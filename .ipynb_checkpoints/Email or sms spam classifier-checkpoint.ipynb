# %%
import pandas as pd

# %%
df=pd.read_csv('spam.csv',encoding="Latin-1")

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %% [markdown]
# ## Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.rename(columns={'v1':'Target','v2':'Text'},inplace=True)

# %%
df.head()
# Out:
#   Target                                               Text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.head()
# Out:
#   Target                                               Text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.isnull().sum()
# Out:
# Target    0
# Text      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 2)

# %%
#EDA

# %%
df['Target'].value_counts()
# Out:
# ham     4516
# spam     653
# Name: Target, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(df['Target'].value_counts(),autopct='%0.2f',labels=['spam','ham'])
plt.show()

# %%
import nltk

# %%
# !pip install nltk
# Out:
# Unable to create process using 'C:\Users\M haris tayyab\anaconda3\python.exe "C:\Users\M haris tayyab\anaconda3\Scripts\pip-script.py" install nltk'

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\M haris
# [nltk_data]     tayyab\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['Text'].apply(len)
# Out:
# 0       111
# 1        29
# 2       155
# 3        49
# 4        61
#        ...
# 5567    161
# 5568     37
# 5569     57
# 5570    125
# 5571     26
# Name: Text, Length: 5169, dtype: int64

# %%
df['characters']=df['Text'].apply(len)

# %%
df.head()
# Out:
#   Target                                               Text  characters
# 0    ham  Go until jurong point, crazy.. Available only ...         111
# 1    ham                      Ok lar... Joking wif u oni...          29
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...         155
# 3    ham  U dun say so early hor... U c already then say...          49
# 4    ham  Nah I don't think he goes to usf, he lives aro...          61

# %%
df['words']=df['Text'].apply(lambda x:len(nltk.word_tokenize(x) ))

# %%
df.head()
# Out:
#   Target                                               Text  characters  words
# 0    ham  Go until jurong point, crazy.. Available only ...         111     24
# 1    ham                      Ok lar... Joking wif u oni...          29      8
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...         155     37
# 3    ham  U dun say so early hor... U c already then say...          49     13
# 4    ham  Nah I don't think he goes to usf, he lives aro...          61     15

# %%
df['sentences']=df['Text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#   Target                                               Text  characters  \
# 0    ham  Go until jurong point, crazy.. Available only ...         111
# 1    ham                      Ok lar... Joking wif u oni...          29
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...         155
# 3    ham  U dun say so early hor... U c already then say...          49
# 4    ham  Nah I don't think he goes to usf, he lives aro...          61
#
#    words  sentences
# 0     24          2
# 1      8          2
# 2     37          2
# 3     13          1
# 4     15          1

# %%
df[['characters','words','sentences']].describe()
# Out:
#         characters        words    sentences
# count  5169.000000  5169.000000  5169.000000
# mean     78.977945    18.453279     1.947185
# std      58.236293    13.324793     1.362406
# min       2.000000     1.000000     1.000000
# 25%      36.000000     9.000000     1.000000
# 50%      60.000000    15.000000     1.000000
# 75%     117.000000    26.000000     2.000000
# max     910.000000   220.000000    28.000000

# %%
df[df['Target']== "ham"][['characters','words','sentences']].describe()
# Out:
#         characters        words    sentences
# count  4516.000000  4516.000000  4516.000000
# mean     70.459256    17.120903     1.799601
# std      56.358207    13.493725     1.278465
# min       2.000000     1.000000     1.000000
# 25%      34.000000     8.000000     1.000000
# 50%      52.000000    13.000000     1.000000
# 75%      90.000000    22.000000     2.000000
# max     910.000000   220.000000    28.000000

# %%
df[df['Target']== "spam"][['characters','words','sentences']].describe()
# Out:
#        characters       words   sentences
# count  653.000000  653.000000  653.000000
# mean   137.891271   27.667688    2.967841
# std     30.137753    7.008418    1.483201
# min     13.000000    2.000000    1.000000
# 25%    132.000000   25.000000    2.000000
# 50%    149.000000   29.000000    3.000000
# 75%    157.000000   32.000000    4.000000
# max    224.000000   46.000000    8.000000

# %%
#Data presprocessing
#lower case
#tokenization //convert to list
#removing special characters
#removing stop words punctuations
#stemming
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\M haris
# [nltk_data]     tayyab\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
from nltk.corpus import stopwords
stopwords.words('english')  
import string
punc=string.punctuation
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
from nltk.corpus import stopwords
def transforming(text):
    text=text.lower()
    text=nltk.word_tokenize(text)
    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)
    text=y[:]
    y.clear()
    for i in text:
        if i not in stopwords.words('english') and i not in punc:
            y.append(i)
    text=y[:]
    y.clear()
    for i in text:
        y.append(ps.stem(i))
    return ' '.join(y)

# %%
transforming('How Are You YT of Haris # loved love haved !!!!')
# Out:
# 'yt hari love love have'

# %%
df['Transform_text']=df['Text'].apply(transforming)

# %%
df.head()
# Out:
#   Target                                               Text  characters  \
# 0    ham  Go until jurong point, crazy.. Available only ...         111
# 1    ham                      Ok lar... Joking wif u oni...          29
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...         155
# 3    ham  U dun say so early hor... U c already then say...          49
# 4    ham  Nah I don't think he goes to usf, he lives aro...          61
#
#    words  sentences                                     Transform_text
# 0     24          2  go jurong point crazi avail bugi n great world...
# 1      8          2                              ok lar joke wif u oni
# 2     37          2  free entri 2 wkli comp win fa cup final tkt 21...
# 3     13          1                u dun say earli hor u c alreadi say
# 4     15          1               nah think goe usf live around though

# %%
from wordcloud import WordCloud
wc=WordCloud(width=500,height=500,min_font_size=10,background_color='black')

# %%
spam_wc = wc.generate(df[df['Target'] == "spam"]["Transform_text"].str.cat(sep=" "))

# %%
plt.imshow(spam_wc)

# %%
ham_wc=wc.generate(df[df['Target']=="ham"]['Transform_text'].str.cat(sep=' '))

# %%
plt.imshow(ham_wc)

# %%
df.head()
# Out:
#   Target                                               Text  characters  \
# 0    ham  Go until jurong point, crazy.. Available only ...         111
# 1    ham                      Ok lar... Joking wif u oni...          29
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...         155
# 3    ham  U dun say so early hor... U c already then say...          49
# 4    ham  Nah I don't think he goes to usf, he lives aro...          61
#
#    words  sentences                                     Transform_text
# 0     24          2  go jurong point crazi avail bugi n great world...
# 1      8          2                              ok lar joke wif u oni
# 2     37          2  free entri 2 wkli comp win fa cup final tkt 21...
# 3     13          1                u dun say earli hor u c alreadi say
# 4     15          1               nah think goe usf live around though

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
df['Target']=encoder.fit_transform(df['Target'])

# %%
df.head()
# Out:
#    Target                                               Text  characters  \
# 0       0  Go until jurong point, crazy.. Available only ...         111
# 1       0                      Ok lar... Joking wif u oni...          29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...         155
# 3       0  U dun say so early hor... U c already then say...          49
# 4       0  Nah I don't think he goes to usf, he lives aro...          61
#
#    words  sentences                                     Transform_text
# 0     24          2  go jurong point crazi avail bugi n great world...
# 1      8          2                              ok lar joke wif u oni
# 2     37          2  free entri 2 wkli comp win fa cup final tkt 21...
# 3     13          1                u dun say earli hor u c alreadi say
# 4     15          1               nah think goe usf live around though

# %% [markdown]
# Model building

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
tfidf=TfidfVectorizer()
cv=CountVectorizer()

# %%
X=tfidf.fit_transform(df["Transform_text"]).toarray()

# %%
X.shape
# Out:
# (5169, 6708)

# %%
y=df['Target'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred=gnb.predict(X_test)
print(accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(precision_score(y_test,y_pred))
# Out:
# 0.8762088974854932
# [[793 103]
#  [ 25 113]]
# 0.5231481481481481

# %%
mnb.fit(X_train,y_train)
y_pred1=mnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.9593810444874274
# [[896   0]
#  [ 42  96]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred2=bnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9700193423597679
# [[893   3]
#  [ 28 110]]
# 0.9734513274336283

# %%
import pickle

# %%
pickle.dump(mnb,open("spam.pkl","wb"))

# %%
pickle.dump(tfidf,open("TfidfVectorizer.pkl","wb"))

# %%
lf=pickle.load(open("TfidfVectorizer.pkl","rb"))

# %%
lf
# Out:
# TfidfVectorizer()

# %%
gh=pickle.load(open("spam.pkl","rb"))

# %%
gh
# Out:
# MultinomialNB()

# %%
msg="Free entry in 2 a wkly comp to win FA Cup fina"
df=[msg]
vt=tfidf.transform(df).toarray()
rslt=mnb.predict(vt)
print(rslt)
# Out:
# [1]
